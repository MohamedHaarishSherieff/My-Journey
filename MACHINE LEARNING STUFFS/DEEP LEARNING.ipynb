# %% [markdown]
# # AGENDA
#     PART-1 Introduction to TensorFlow for Artificial Intelligence and Deep Learning
#     PART-2 Convolutional Neural Networks in TensorFlow
#     PART-3 Natural Language Processing in TensorFlow
#     PART-4 Sequences, Time Series and Prediction
# IN THESE PARTS WE WILL HAVE DIFFERENT WEEKS TO SEPERATE OUR WORKS INSIDE IT!

# %% [markdown]
# # PART-1 Introduction to TensorFlow for Artificial Intelligence and Deep Learning

# %% [markdown]
# # BASIC DIFFERENCE B\W TRADITIONAL PROGRAMMING AND MACHINE LEARNING!
# ![image.png](attachment:image.png)

# %% [markdown]
# # WEEK-1

# %%
import tensorflow as tf
import keras
import numpy as np
import pandas as pd

# %%
model = keras.Sequential([keras.layers.Dense(units=1,input_shape = [1])])
# 1-HERE WE USE THE WORD "DENSE"-- IS TO DEFINE A LAYER OF CONNECTED NEURONS!
# (IN THIS CASE WE JUST HAVE 1 LAYER...HENCE OUR "UNITS = 1")..SO IT'S A SINGLE NEURON
# 2-SUCCESIVE LAYERS ARE DEFINED IN SEQUENCE...
# HENCE WE USE THE THE WORD "SEQUENTIAL"!
# 3-WE DEFINE THE SHAPE OF WHAT'S INPUT TO THE NEURAL NETWORK IN THE FIRST...
# (AND IN THIS CASE THERE IS ONLY ONE LAYER)...AND WE CAN SEE THAT...OUR 
# "INPUT_SHAPE" IS JUST A SINGLE VALUE!

# %%
model.compile(optimizer= 'sgd',loss = 'mean_squared_error')
# BOTH THESE "OPTIMIZER" AND "LOSS" ARE THE FUNCTIONS PRESENT IN KERAS(TENSORFLOW)
# THESE FUNCTIONS HAS A HELL LOT OF MATHEMATICS..IMPLEMENTED WITHIN THEM!
#(NOTE- JUST LIKE THIS MANY FUNCTIONS ARE THERE!)

# %% [raw]
# WKT...IN MACHINE LEARNING THE MACHINE ACTUALLY GOES THROUGH A HELL LOT OF TRIAL AND ERROR METHOD!
# AND AFTER DOING THIS PROCESS REPEATEDLY AT CERTAIN POINT THE ACCURACY REACHES 100%..AND THE WORK STOPS...THE PROCEDURE WOULD HAPPEN IN THIS PLACE...WHERE THE "LOSS FUNCTION" MEASURES THE DATA AND THE "OPTIMIZER" CHECKS HOW GOOD IS THE DATA?....THIS PROCESS GETS REPEATED UNTILL IT FINDS A  CERTAIN POINT WHERE THE ACCURACY WOULD GET 100%!

# %%
xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0])
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0])

# %%
#TRAINING THE MODEL!
model.fit(xs,ys,epochs = 500) 
#epochs = 500 means...the program will go the training loop for 500 times!
# Out:
# Epoch 1/500
# 1/1 [==============================] - 43s 43s/step - loss: 10.5200
# Epoch 2/500
# 1/1 [==============================] - 0s 20ms/step - loss: 8.4907
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 6.8898
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 5.6259
# Epoch 5/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.6273
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.8375
# Epoch 7/500
# 1/1 [==============================] - 0s 5ms/step - loss: 3.2122
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.7162
# Epoch 9/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3221
# Epoch 10/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.0082
# Epoch 11/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.7575
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.5567
# ...

# %%
print(model.predict([10.0]))
#THE ACTUAL ANSWER WOULD BE 19...BUT OUR PROGRAM WOULD SHOW A VALUE THAT IS VERY CLOSE TO 19!
# Out:
# [[18.982662]]

# %% [markdown]
# # NOW WE ARE GONNA DEAL WITH RECOGNIZING IMAGES!
# EXERCISE-1

# %%
import tensorflow as tf
from tensorflow import keras
mnist= tf.keras.datasets.fashion_mnist
(train_images,train_labels),(test_images,test_labels)= mnist.load_data()

# %%
# VISUALIZING SOME RANDOM IMAGES IN OUR DATA WITH THEIR RESPECTIVE LABELS!
import matplotlib.pyplot as plt
plt.imshow(train_images[0])
# print(train_images[0]) this line would show you the matrix behind the image!
print(train_labels[0]) #HERE THE LABEL WOULD BE "9"!
# Out:
# 9

# %%
# VISUALIZING SOME RANDOM IMAGES IN OUR DATA WITH THEIR RESPECTIVE LABELS!
import matplotlib.pyplot as plt
plt.imshow(train_images[42])
# print(train_images[42]) this line would show you the matrix behind the image!
print(train_labels[42]) #HERE THE LABEL WOULD BE "9"!
# Out:
# 9

# %% [raw]
# WKT,OUR IMAGES HAS VALUES FROM ZERO TO 255...BUT THEN....AS NEURAL NETWORKS WORKS BETTER WITH NORMALIZED DATA!....WE ARE GONNA CHANGE THE VALUES OF OUR IMAGES...B\W "ZEROS AND ONE"!
# SIMPLY BY DIVIDING EVERY VALUE BY "255"!

# %%
train_images = train_images / 255
test_images = test_images / 255

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation=tf.nn.relu), 
    # RELU-It is a piecewise linear function that will output the input directly if it is positive,
    #otherwise, it will output zero
    keras.layers.Dense(10,activation=tf.nn.softmax)
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(),
             loss= "sparse_categorical_crossentropy",
             metrics=['accuracy'])
model.fit(train_images,train_labels,epochs = 5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.4969 - accuracy: 0.8252
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3731 - accuracy: 0.8650
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3364 - accuracy: 0.8784
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3113 - accuracy: 0.8857
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2939 - accuracy: 0.8906

# %%
model.evaluate(test_images,test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3563 - accuracy: 0.8719
# [0.3562794327735901, 0.8719000220298767]

# %%
classifications = model.predict(test_images)

print(classifications[0])
# Out:
# [5.4280315e-07 3.9848803e-08 9.3099246e-08 2.5003648e-09 1.6850629e-08
#  1.6358627e-02 4.6950524e-07 1.3002169e-01 5.3343052e-07 8.5361797e-01]

# %%
print(test_labels[0])
# Out:
# 9

# %% [markdown]
# # WEEK-2
# EXERCISE-2

# %%
mnist = tf.keras.datasets.mnist

(training_images, training_labels) ,  (test_images, test_labels) = mnist.load_data()

training_images = training_images/255.0
test_images = test_images/255.0

model = tf.keras.models.Sequential([tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(1024, activation=tf.nn.relu), #experimenting with this layer
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)])

model.compile(optimizer = 'adam',
              loss = 'sparse_categorical_crossentropy')

model.fit(training_images, training_labels, epochs=5)

model.evaluate(test_images, test_labels)

classifications = model.predict(test_images)

print(classifications[0])
print(test_labels[0])
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 26s 13ms/step - loss: 0.1837 0s - loss: 0.183
# Epoch 2/5
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.0726
# Epoch 3/5
# 1875/1875 [==============================] - 25s 13ms/step - loss: 0.0491
# Epoch 4/5
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.0348 0s - loss: 0
# Epoch 5/5
# ...
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0694
# [3.1054810e-08 4.3390940e-09 1.2787413e-07 1.7259083e-07 1.2968503e-12
#  1.8675909e-10 7.8132467e-14 9.9999964e-01 3.2466946e-10 1.3222628e-07]
# 7

# %% [markdown]
# # USAGE OF CALLBACKS TO CONTROL TRAINING!

# %%
class myCallback(tf.keras.callbacks.Callback):
        def on_epoch_end(self,epoch,logs={}):
            if (logs.get('loss')< 0.4):
                print("\nLoss is low so cancelling training!")
                self.model.stop_training= True

# %%
callback = myCallback()
mnist = tf.keras.datasets.mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images/255.0 
test_images=test_images/255.0 
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')
model.fit(training_images, training_labels, epochs=5,callbacks = [callback])
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2036
#
# Loss is low so cancelling training!

# %%
# ANOTHER EXAMPLE!
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy')>0.6):
            print("\nReached 60% accuracy so cancelling training!")
            self.model.stop_training = True

mnist = tf.keras.datasets.fashion_mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

callbacks = myCallback()

model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(512, activation=tf.nn.relu),
  tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])
model.compile(optimizer=tf.optimizers.Adam(),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=100, callbacks=[callbacks])
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 17s 8ms/step - loss: 0.4722 - accuracy: 0.8321
#
# Reached 60% accuracy so cancelling training!

# %% [markdown]
# # WEEK-3

# %% [raw]
# UNTILL NOW WE WERE DEALING WITH THE DATA JUST BY LOOKING AT EVERY PIXEL IN THE IMAGES...RATHER THAN HAVING A CLEAR PERSPECTIVE ABOUT THE FEATURES OF THE IMAGE THAT HELPS TO DENOTE A
# "SHOE AS A SHOE"....OR...."SHIRT AS A SHIRT"!
# SO IN THE UPCOMING STUFFS...WE ARE GONNA DEAL WITH THIS...THAT IS FINDING THE FEATURES THAT
# HELPS TO MAKE THE GUESS BY OUR MACHINE!...AND THIS CAN BE DONE BY
# CONVOLUTIONAL NEURAL NETWORK!

# %% [markdown]
# # CONVOLUTIONAL NEURAL NETWORK!
# ![image.png](attachment:image.png)
# AS THE PIC SHOWS..."CONVOLUTION"...FILTERS THE CURRENT PIXELS OF THE IMAGE AND GIVES A NEW PIXEL VALUE WITH SOME PRECISED FEATURES THAT DENOTES A "SHOE AS A SHOE"!....

# %% [markdown]
# # NOTE- when we combine CONVOLUTION with pooling, they can become really powerful!
# pooling- It is a way of compressing an image.
#
# FOR EXAMPLE(POOLING):-
# ![image.png](attachment:image.png)
# IN THIS IMAGE WE ARE COMPRESSING 16 PIXELS INTO 4 PIXELS!

# %%
# IMPLEMENTING CONVOLUTIONAL LAYERS AND POOLING LAYERS!
import tensorflow as tf
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()
training_images=training_images.reshape(60000, 28, 28, 1)
training_images=training_images / 255.0
test_images = test_images.reshape(10000, 28, 28, 1)
test_images=test_images/255.0
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(28, 28, 1)),
    #HERE..."64"- ASKING KERAS TO GENERATE 64 FILTERS FOR US!
    #....."(3,3)"- IT REPRESENTS THAT THESE FILTERS ARE....3-BY-3!
    #....."28,28,1"- (28,28) REPRESENTS THE INPUT SHAPE 
    # AND "1" MEANS THAT WE ARE TALLYING USING A SINGLE BYTE FOR COLOR DEPTH
    # (AS OUR IMAGES ARE GREY SCALED)...WE JUST USE ONE BYTE!
  tf.keras.layers.MaxPooling2D(2, 2),
    #HERE POOLING IS MENTIONED AS "MaxPooling" COZ...WE ARE GONNA TAKE THE "MAXIMUM VALUE"!
    #We're saying it's a two-by-two pool, so for every four pixels...
    #the biggest one will survive as shown earlier IN THE IMAGE!
  tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
  tf.keras.layers.MaxPooling2D(2,2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(10, activation='softmax')
])
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
model.fit(training_images, training_labels, epochs=5)
test_loss = model.evaluate(test_images, test_labels)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 26, 26, 64)        640
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 1600)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               204928
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                1290
# ...

# %% [raw]
# AS COMPARED TO OUR PREVIOUS LOSS AND ACCURACY....
# OUR NEW HAS RAISEN AND OUR NEW LOSS HAS BEEN REDUCED!

# %%
# VISUALIZING THE CONVOLUTIONS AND POOLING LAYERS...WITH MATPLOTLIB
print(test_labels[:100])
# AT 1ST...WE ARE PRINTING THE 1ST 100 LABELS!
# Out:
# [9 2 1 1 6 1 4 6 5 7 4 5 7 3 4 1 2 4 8 0 2 5 7 9 1 4 6 0 9 3 8 8 3 3 8 0 7
#  5 7 9 6 1 3 7 6 7 2 1 2 2 4 4 5 8 2 2 8 4 8 0 7 7 8 5 1 1 2 3 9 8 7 0 2 6
#  2 3 1 2 8 4 1 8 5 9 5 0 3 2 0 6 5 3 6 7 1 8 0 1 4 2]

# %%
import matplotlib.pyplot as plt
f, axarr = plt.subplots(3,4)
FIRST_IMAGE=0
SECOND_IMAGE=7
THIRD_IMAGE=26
CONVOLUTION_NUMBER = 1
from tensorflow.keras import models
layer_outputs = [layer.output for layer in model.layers]
activation_model = tf.keras.models.Model(inputs = model.input, outputs = layer_outputs)
for x in range(0,4):
    f1 = activation_model.predict(test_images[FIRST_IMAGE].reshape(1, 28, 28, 1))[x]
    axarr[0,x].imshow(f1[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
    axarr[0,x].grid(False)
    f2 = activation_model.predict(test_images[SECOND_IMAGE].reshape(1, 28, 28, 1))[x]
    axarr[1,x].imshow(f2[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
    axarr[1,x].grid(False)
    f3 = activation_model.predict(test_images[THIRD_IMAGE].reshape(1, 28, 28, 1))[x]
    axarr[2,x].imshow(f3[0, : , :, CONVOLUTION_NUMBER], cmap='inferno')
    axarr[2,x].grid(False)

# %% [markdown]
# # WEEK-4

# %% [markdown]
# In the earlier examples with a fashion-data...WE used a built-in dataset. All of the data was handily split into training and test sets for US and labels were available. In many scenarios, that's not going to be the case and WE'LL HAVE TO DO IT BY OURSELVES!....In some cases, there may even be multiple subjects....

# %% [markdown]
# In this lesson, we'll take a look at some of the APIs that are available to make IT easier for US. In particular, THE IMAGE GENERATOR in TensorFlow. One feature of the IMAGE GENERATOR is that WE can point it at a directory and then the sub-directories of that will automatically generate labels for US!
# ![image.png](attachment:image.png)
# So for example, consider this directory structure. WE have an images directory and in that,WE have sub-directories for training and validation. When WE put sub-directories in these for horses and humans and store the requisite images in there, the image generator can create a feeder for those images and auto label them for US.
#
#     if WE point an image generator at the training directory, the labels will be horses and
#     humans and all of the images in each directory will be loaded and labeled accordingly.
#
#     Similarly, if WE point one at the validation directory, the same thing will happen.

# %% [markdown]
# # LETS TAKE A LOOK AT THIS IN CODE!
# # LAB-1
# https://github.com/https-deeplearning-ai/tensorflow-1-public/blob/main/C1/W4/ungraded_labs/C1_W4_Lab_1_image_generator_no_validation.ipynb
# HERE I'VE PROVIDED THIS LINK INSTEAD OF TYPING THE CODE....COZ THE CODE IS REALLY HUGE WITH HELL LOT OF CONFUSIONS...SO IT WOULD BE BETTER IN ORDER TO GO THROUGH THIS LINK TO UNDERSTAND ABOUT THIS IN A BETTER MANNER!

# %% [markdown]
# # LAB-2
# https://github.com/https-deeplearning-ai/tensorflow-1-public/blob/main/C1/W4/ungraded_labs/C1_W4_Lab_2_image_generator_with_validation.ipynb

# %% [markdown]
# # LAB-3
# https://github.com/https-deeplearning-ai/tensorflow-1-public/blob/main/C1/W4/ungraded_labs/C1_W4_Lab_3_compacted_images.ipynb

# %% [markdown]
# # PART-2 Convolutional Neural Networks in TensorFlow

# %% [markdown]
# # WEEK-1
# In the first course, we learned how to use TensorFlow to implement a basic neural network, going up all the way to basic Convolutional Neural Network. In this second course(first week) We take the ideas we've learned and apply them to a much bigger dataset of cats versus dogs. Yes so we take the full Kaggle dataset of 25,000 cats versus dogs images.

# %% [markdown]
# # LAB-1
# IN ORDER TO UNDERSTAND THIS WEEK'S STUFFS...GO THROUGH THIS NOTEBOOK(DOING THIS IS MORE THAN ENOUGH!)
# https://github.com/https-deeplearning-ai/tensorflow-1-public/blob/main/C2/W1/ungraded_lab/C2_W1_Lab_1_cats_vs_dogs.ipynb
# # EXERCISE!
# https://github.com/agniiyer/TensorFlow-in-Practice-Specialization/blob/master/2.%20Convolutional%20Neural%20Networks%20in%20TensorFlow/Exercises/Exercise%205%20-%20Real%20World%20Scenarios/Exercise_1_Cats_vs_Dogs_Question-FINAL.ipynb

# %% [markdown]
# # WEEK-2
# AUGMENTATION....A TECHNIQUE TO AVOID "OVER FITTING"!

# %% [markdown]
# NOTE-the less data you have, the less chance you have of getting accurate predictions for data that your model hasn't yet seen.
#
# To put it simply, if you are training a model to spot cats, and your model has never seen what a cat looks like when lying down, it might not recognize that in future.
#
# Augmentation simply amends your images on-the-fly while training using transforms like rotation. So, it could 'simulate' an image of a cat lying down by rotating a 'standing' cat by 90 degrees. As such you get a cheap way of extending your dataset beyond what you have already

# %% [markdown]
# # LAB-1
# HERE WE ARE GONNA SEE ABOUT THE "CAT VS DOG" MODEL'S PERFORMANCE WITHOUT USING THE AUGMENTATION...
#
# NOTE-BY THIS OUR MODEL WOULD GET OVERFITTED FOR SURE :)
# https://github.com/https-deeplearning-ai/tensorflow-1-public/blob/main/C2/W2/ungraded_labs/C2_W2_Lab_1_cats_v_dogs_augmentation.ipynb

# %% [markdown]
# # LAB-2
# HERE WE ARE GONNA ADD THE AUGMENTATION OUR "CAT VS DOG" TRAINING DATASET AND IN RESULT...WE WOULD SOLVE THE PROBLEM OF OVER FITTING!
# https://github.com/https-deeplearning-ai/tensorflow-1-public/blob/main/C2/W2/ungraded_labs/C2_W2_Lab_2_horses_v_humans_augmentation.ipynb

# %% [markdown]
# This week WE looked at the really useful tool that TensorFlow gives US with Image Augmentation. With it, WE can effectively simulate a larger dataset from a smaller one with tools to move images around the frame, skew them, rotate them, and more. It can be an effective tool in fixing overfitting!

# %% [markdown]
# # EXERCISE
# https://github.com/agniiyer/TensorFlow-in-Practice-Specialization/blob/master/2.%20Convolutional%20Neural%20Networks%20in%20TensorFlow/Exercises/Exercise%206%20-%20Cats%20v%20Dogs%20with%20Augmentation/Exercise_2_Cats_vs_Dogs_using_augmentation_Question-FINAL.ipynb

# %% [markdown]
# # WEEK-3

# %% [markdown]
# TRANSFER LEARNING-
#
# Transfer learning means taking the relevant parts of a pre-trained machine learning model and applying it to a new but similar problem...!

# %% [markdown]
# # LAB-1
# TRANSFER LEARNING-EXAMPLE!("INCEPTION MODEL")
# https://github.com/https-deeplearning-ai/tensorflow-1-public/blob/main/C2/W3/ungraded_lab/C2_W3_Lab_1_transfer_learning.ipynb

# %% [markdown]
# DROPOUTS:-
# The idea behind Dropouts is that they remove a random number of neurons in your neural network. This works very well for two reasons: The first is that neighboring neurons often end up with similar weights, which can lead to overfitting, so dropping some out at random can remove this. The second is that often a neuron can over-weigh the input from a neuron in the previous layer, and can over specialize as a result.

# %% [markdown]
# # LAB-2(JUST THE SAME NOTEBOOK(LAB-1))
# APPLYING TRANSFER LEARNING TO CATS VS DOGS...WITH DROPOUTS!
# https://github.com/https-deeplearning-ai/tensorflow-1-public/blob/main/C2/W3/ungraded_lab/C2_W3_Lab_1_transfer_learning.ipynb

# %% [markdown]
# # EXERCISE
# https://github.com/agniiyer/TensorFlow-in-Practice-Specialization/blob/master/2.%20Convolutional%20Neural%20Networks%20in%20TensorFlow/Exercises/Exercise%207%20-%20Transfer%20Learning/Exercise_3_Horses_vs_humans_using_Transfer_Learning_Question-FINAL.ipynb

# %% [markdown]
# # WEEK-4
# MULTICLASS CLASSIFICATIONS!
#
# In the last few lessons, WE've been building a binary classifier. One which detects two different types of objects, horse or human-cat or dog...that type of thing. In this lesson, we'll take a look at how we can extend that for multiple classes.
#
# SAMPLE STRUCTURE!
# ![image.png](attachment:image.png)

# %% [markdown]
# # LAB-1
# ROCK PAPER SCISSORS!
#
# https://github.com/https-deeplearning-ai/tensorflow-1-public/blob/main/C2/W4/ungraded_lab/C2_W4_Lab_1_multi_class_classifier.ipynb

# %% [markdown]
# # EXERCISE!
# https://render.githubusercontent.com/view/ipynb?color_mode=auto&commit=c284a2179b742cb669afee0370bd91b94077d9d7&enc_url=...&nwo=R-aryan%2FTensorFlow-In-Practise-Specialization-Coursera&path=Course+2-+Convolutional+Neural+Network%28CNN%29+in+Tensorflow%2FWeek-4%2FExercise_4_Multi_class_classifier_Question-FINAL.ipynb&repository_id=278012278&repository_type=Repository

# %% [markdown]
# In PART-2 WE spent a lot of time going over Convolutional Neural Networks, exploring how to use them with large datasets, take advantage of Augmentation, Dropouts, Regularization and Transfer learning, and of course looking at the coding considerations between binary or multi-class classification.
#
# In Course 3, you'll switch gears and continue with Natural Language Processing, and in particular, work with texts.
# # THE END(PART-2)

# %% [markdown]
# # PART-3 Natural Language Processing in TensorFlow
# IN THIS COURSE....WE'LL LEARN HOW TO DEAL WITH
# TEXTS USING TENFSORFLOW!
# # WEEK-1

# %% [markdown]
# The first step in understanding sentiment in text, and in particular when training a neural network to do so is the tokenization of that text. This is the process of converting the text into numeric values, with a number representing a word or a character. This week you'll learn about the Tokenizer and pad_sequences APIs in TensorFlow and how they can be used to prepare and encode text and sentences to get them ready for training neural networks!

# %% [markdown]
# # USING APIs(TOKENIZER)

# %%
#LAB-1
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer

sentences = [
    'i love my dog',
    'I, love my cat',
    'You love my dog!'
]

tokenizer = Tokenizer(num_words = 100)
tokenizer.fit_on_texts(sentences)
word_index = tokenizer.word_index
print(word_index)
# Out:
# {'love': 1, 'my': 2, 'i': 3, 'dog': 4, 'cat': 5, 'you': 6}

# %% [markdown]
# # LAB-2
# HERE WE SEE ABOUT "texts_to_sequences",PADDING(pad_sequences)AND STUFFS!
# https://github.com/https-deeplearning-ai/tensorflow-1-public/blob/main/C3/W1/ungraded_labs/C3_W1_Lab_2_sequences_basic.ipynb

# %% [markdown]
# # LAB-3
# PLAYING WITH SARCASM DATASET!
# https://github.com/https-deeplearning-ai/tensorflow-1-public/blob/main/C3/W1/ungraded_labs/C3_W1_Lab_3_sarcasm.ipynb

# %% [markdown]
# # EXERCISE!
# https://colab.research.google.com/github/https-deeplearning-ai/tensorflow-1-public/blob/adding_C3/C3/W1/assignment/C3_W1_Assignment_Solution.ipynb

# %% [markdown]
# # WEEK-2
# Last week WE saw how to use the Tokenizer to prepare OUR text to be used by a neural network by converting words into numeric tokens, and sequencing sentences from these tokens. This week WE'll learn about Embeddings, where these tokens are mapped as vectors in a high dimension space. With Embeddings and labelled examples, these vectors can then be tuned so that words with similar meaning will have a similar direction in the vector space. This will begin the process of training a neural network to understand sentiment in text -- and you'll begin by looking at movie reviews, training a neural network on texts that are labelled 'positive' or 'negative' and determining which words in a sentence drive those meanings.

# %%
5!=6
# Out:
# True

# %%
# Out:
# 1024.0
